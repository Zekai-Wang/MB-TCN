# %%
from data_processing import *
from MBTCN_Module import *
from training_evaluation import *

import sys
import numpy as np
import pandas as pd
import sklearn
import torch
from torch import nn
import torch.optim as optim
import torch.nn.functional as F


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("Python Version:", sys.version)
print('Pytorch Version:', torch.__version__)
print('Numpy Version:', np.__version__)
print('Pandas Version:', pd.__version__)
print('Sklearn Version:', sklearn.__version__)
print('===========================================')
print("Num GPUs Available: ",  torch.cuda.device_count())
print('===========================================')
print('Device Information:',torch.cuda.get_device_name(0))
# Out:
# Python Version: 3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]
# Pytorch Version: 1.13.1
# Numpy Version: 1.23.4
# Pandas Version: 2.0.3
# Sklearn Version: 1.2.2
# ===========================================
# Num GPUs Available:  1
# ===========================================
# Device Information: NVIDIA RTX A4500

# %%
# read data from psv file, two data files from https://physionet.org/content/challenge-2019/1.0.0/
list_A, list_B = load_data_list('training/training/','training_setB/training_setB/')

#create training and test missingness mask
mask_A, mask_B = missing_mask_matrix(list_A, list_B)

#fill nan
list_A, list_B = fill_nan(list_A, list_B)

#split predictors and response from lists
A_predictors, B_predictors, A_label, B_label = split_predictor_response(list_A, list_B) 

#get training sample indice
sepsis_index_A, nonsepsis_index_A = get_index(A_label)
sepsis_index_B, nonsepsis_index_B = get_index(B_label)

#pads sequences to the same length (3D tensor): SHAPE (N, L, C)
A_padded = create_tensor(A_predictors, padding_value=0)
B_padded = create_tensor(B_predictors, padding_value=0)
A_mask_padded = create_tensor(mask_A, padding_value=0)
B_mask_padded = create_tensor(mask_B, padding_value=0)

# reshape (N, C, L)
A_padded = A_padded.reshape(-1, 40, 336)
B_padded = B_padded.reshape(-1, 40, 336)
A_mask_padded = A_mask_padded.reshape(-1, 40, 336)
B_mask_padded = B_mask_padded.reshape(-1, 40, 336)

# %%
print("Summary Information:")
print('----------------------'*2)
total = len(sepsis_index_A) + len(nonsepsis_index_A)
print('Training set:\n    Total: {}\n    Positive: {} ({:.2f}% of total)\n'.format(
    total, len(sepsis_index_A), 100 * len(sepsis_index_A) / total))
print('----------------------'*2)
total2 = len(sepsis_index_B) + len(nonsepsis_index_B)
print('Testing set:\n    Total: {}\n    Positive: {} ({:.2f}% of total)\n'.format(
    total2, len(sepsis_index_B), 100 * len(sepsis_index_B) / total2))
# Out:
# Summary Information:
# --------------------------------------------
# Training set:
#     Total: 20336
#     Positive: 1790 (8.80% of total)
#
# --------------------------------------------
# Testing set:
#     Total: 20000
#     Positive: 1142 (5.71% of total)

# %%
# initialize MB-TCN model

num_inputs = 40
num_channels = [16,16]
n_outputs = 1
n_branches = 10              
kernel_size = 10
dropout = 0.4
batch_size = 128

model = MBTCN(num_inputs = num_inputs, 
              num_channels = num_channels, 
              n_outputs = n_outputs, 
              n_branches = n_branches,                 
              kernel_size = kernel_size, 
              dropout = dropout).to(device)

criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters())

#create training set
subset_list = create_subsets(A_padded, A_label, A_mask_padded, n_subsets = 10, minority_class = 1)

#create validation set (in this demo, I select training_B from physionet.org as validation set)
val_loader = val_create(B_padded, B_label, B_mask_padded)

# %%
# Training the model
num_epochs = 60
train_model(sublist = subset_list, 
            val_loader = val_loader, 
            model = model, 
            criterion = criterion, 
            optimizer = optimizer, 
            num_epochs = num_epochs, 
            MB_NUM = n_branches, 
            batch_size = batch_size)
# Out:
# Loss: 0.4243 - Accuracy: 0.9349 - Recall: 0.0053 - Precision: 0.0349 - F1: 0.0091 - AUC: 0.6183 - PR Curve Score: 0.0969
# Epoch 1/60 - Train Loss: 3.2477 - Val Loss: 0.4243
# Loss: 0.9714 - Accuracy: 0.9032 - Recall: 0.5911 - Precision: 0.3148 - F1: 0.4108 - AUC: 0.7910 - PR Curve Score: 0.3762
# Epoch 2/60 - Train Loss: 2.8337 - Val Loss: 0.9714
# Loss: 1.2413 - Accuracy: 0.8406 - Recall: 0.6839 - Precision: 0.2165 - F1: 0.3288 - AUC: 0.8159 - PR Curve Score: 0.3858
# Epoch 3/60 - Train Loss: 2.5160 - Val Loss: 1.2413
# Loss: 1.2404 - Accuracy: 0.8639 - Recall: 0.6699 - Precision: 0.2460 - F1: 0.3598 - AUC: 0.8213 - PR Curve Score: 0.3983
# Epoch 4/60 - Train Loss: 2.4933 - Val Loss: 1.2404
# Loss: 1.5224 - Accuracy: 0.6137 - Recall: 0.7933 - Precision: 0.1079 - F1: 0.1900 - AUC: 0.8143 - PR Curve Score: 0.3908
# Epoch 5/60 - Train Loss: 2.4199 - Val Loss: 1.5224
# Loss: 1.2884 - Accuracy: 0.7100 - Recall: 0.7461 - Precision: 0.1339 - F1: 0.2271 - AUC: 0.8142 - PR Curve Score: 0.3892
# Epoch 6/60 - Train Loss: 2.4136 - Val Loss: 1.2884
# Loss: 1.2572 - Accuracy: 0.8266 - Recall: 0.7084 - Precision: 0.2051 - F1: 0.3181 - AUC: 0.8332 - PR Curve Score: 0.4068
# Epoch 7/60 - Train Loss: 2.3145 - Val Loss: 1.2572
# Loss: 1.1948 - Accuracy: 0.8406 - Recall: 0.7014 - Precision: 0.2195 - F1: 0.3344 - AUC: 0.8365 - PR Curve Score: 0.4118
# Epoch 8/60 - Train Loss: 2.2768 - Val Loss: 1.1948
# Loss: 1.3121 - Accuracy: 0.7503 - Recall: 0.7609 - Precision: 0.1555 - F1: 0.2582 - AUC: 0.8351 - PR Curve Score: 0.4182
# Epoch 9/60 - Train Loss: 2.2029 - Val Loss: 1.3121
# Loss: 1.2648 - Accuracy: 0.8101 - Recall: 0.7434 - Precision: 0.1949 - F1: 0.3089 - AUC: 0.8423 - PR Curve Score: 0.4194
# Epoch 10/60 - Train Loss: 2.2077 - Val Loss: 1.2648
# Loss: 1.2688 - Accuracy: 0.8160 - Recall: 0.7487 - Precision: 0.2013 - F1: 0.3173 - AUC: 0.8526 - PR Curve Score: 0.4330
# Epoch 11/60 - Train Loss: 2.1697 - Val Loss: 1.2688
# Loss: 1.2674 - Accuracy: 0.8178 - Recall: 0.7434 - Precision: 0.2022 - F1: 0.3179 - AUC: 0.8543 - PR Curve Score: 0.4298
# Epoch 12/60 - Train Loss: 2.1486 - Val Loss: 1.2674
# Loss: 1.2426 - Accuracy: 0.8405 - Recall: 0.7215 - Precision: 0.2229 - F1: 0.3406 - AUC: 0.8515 - PR Curve Score: 0.4292
# Epoch 13/60 - Train Loss: 2.1467 - Val Loss: 1.2426
# Loss: 1.2961 - Accuracy: 0.8320 - Recall: 0.7338 - Precision: 0.2153 - F1: 0.3329 - AUC: 0.8573 - PR Curve Score: 0.4359
# Epoch 14/60 - Train Loss: 2.1331 - Val Loss: 1.2961
# Loss: 1.2785 - Accuracy: 0.8283 - Recall: 0.7496 - Precision: 0.2137 - F1: 0.3326 - AUC: 0.8630 - PR Curve Score: 0.4434
# Epoch 15/60 - Train Loss: 2.1329 - Val Loss: 1.2785
# Loss: 1.3326 - Accuracy: 0.7947 - Recall: 0.7776 - Precision: 0.1873 - F1: 0.3019 - AUC: 0.8634 - PR Curve Score: 0.4480
# Epoch 16/60 - Train Loss: 2.1058 - Val Loss: 1.3326
# Loss: 1.2353 - Accuracy: 0.8438 - Recall: 0.7277 - Precision: 0.2280 - F1: 0.3473 - AUC: 0.8586 - PR Curve Score: 0.4407
# Epoch 17/60 - Train Loss: 2.0854 - Val Loss: 1.2353
# Loss: 1.2086 - Accuracy: 0.8471 - Recall: 0.7303 - Precision: 0.2327 - F1: 0.3529 - AUC: 0.8599 - PR Curve Score: 0.4446
# Epoch 18/60 - Train Loss: 2.0788 - Val Loss: 1.2086
# Loss: 1.2262 - Accuracy: 0.8401 - Recall: 0.7356 - Precision: 0.2249 - F1: 0.3445 - AUC: 0.8647 - PR Curve Score: 0.4514
# Epoch 19/60 - Train Loss: 2.0570 - Val Loss: 1.2262
# Loss: 1.2514 - Accuracy: 0.8414 - Recall: 0.7443 - Precision: 0.2278 - F1: 0.3489 - AUC: 0.8670 - PR Curve Score: 0.4471
# Epoch 20/60 - Train Loss: 2.0519 - Val Loss: 1.2514
# Loss: 1.3410 - Accuracy: 0.8123 - Recall: 0.7627 - Precision: 0.2000 - F1: 0.3169 - AUC: 0.8648 - PR Curve Score: 0.4486
# Epoch 21/60 - Train Loss: 2.0416 - Val Loss: 1.3410
# Loss: 1.2785 - Accuracy: 0.8369 - Recall: 0.7408 - Precision: 0.2220 - F1: 0.3416 - AUC: 0.8628 - PR Curve Score: 0.4527
# Epoch 22/60 - Train Loss: 2.0622 - Val Loss: 1.2785
# Loss: 1.2610 - Accuracy: 0.8566 - Recall: 0.7207 - Precision: 0.2440 - F1: 0.3646 - AUC: 0.8612 - PR Curve Score: 0.4494
# Epoch 23/60 - Train Loss: 2.0226 - Val Loss: 1.2610
# Loss: 1.2815 - Accuracy: 0.8206 - Recall: 0.7531 - Precision: 0.2065 - F1: 0.3241 - AUC: 0.8630 - PR Curve Score: 0.4518
# Epoch 24/60 - Train Loss: 2.0291 - Val Loss: 1.2815
# Loss: 1.3308 - Accuracy: 0.8404 - Recall: 0.7329 - Precision: 0.2248 - F1: 0.3440 - AUC: 0.8608 - PR Curve Score: 0.4461
# Epoch 25/60 - Train Loss: 2.0049 - Val Loss: 1.3308
# Loss: 1.1754 - Accuracy: 0.8661 - Recall: 0.7215 - Precision: 0.2588 - F1: 0.3810 - AUC: 0.8624 - PR Curve Score: 0.4506
# Epoch 26/60 - Train Loss: 2.0139 - Val Loss: 1.1754
# Loss: 1.2151 - Accuracy: 0.8621 - Recall: 0.7329 - Precision: 0.2545 - F1: 0.3778 - AUC: 0.8680 - PR Curve Score: 0.4587
# Epoch 27/60 - Train Loss: 2.0143 - Val Loss: 1.2151
# Loss: 1.1591 - Accuracy: 0.8228 - Recall: 0.7574 - Precision: 0.2093 - F1: 0.3280 - AUC: 0.8676 - PR Curve Score: 0.4659
# Epoch 28/60 - Train Loss: 2.0099 - Val Loss: 1.1591
# Loss: 1.1990 - Accuracy: 0.8680 - Recall: 0.7320 - Precision: 0.2638 - F1: 0.3878 - AUC: 0.8761 - PR Curve Score: 0.4642
# Epoch 29/60 - Train Loss: 1.9863 - Val Loss: 1.1990
# Loss: 1.2361 - Accuracy: 0.8365 - Recall: 0.7539 - Precision: 0.2236 - F1: 0.3450 - AUC: 0.8749 - PR Curve Score: 0.4632
# Epoch 30/60 - Train Loss: 1.9976 - Val Loss: 1.2361
# Loss: 1.1794 - Accuracy: 0.8470 - Recall: 0.7539 - Precision: 0.2366 - F1: 0.3602 - AUC: 0.8775 - PR Curve Score: 0.4653
# Epoch 31/60 - Train Loss: 1.9822 - Val Loss: 1.1794
# Loss: 1.1271 - Accuracy: 0.8691 - Recall: 0.7198 - Precision: 0.2635 - F1: 0.3857 - AUC: 0.8743 - PR Curve Score: 0.4594
# Epoch 32/60 - Train Loss: 1.9733 - Val Loss: 1.1271
# Loss: 1.2227 - Accuracy: 0.8445 - Recall: 0.7478 - Precision: 0.2323 - F1: 0.3545 - AUC: 0.8775 - PR Curve Score: 0.4596
# Epoch 33/60 - Train Loss: 1.9675 - Val Loss: 1.2227
# Loss: 1.2096 - Accuracy: 0.8419 - Recall: 0.7557 - Precision: 0.2304 - F1: 0.3531 - AUC: 0.8745 - PR Curve Score: 0.4593
# Epoch 34/60 - Train Loss: 1.9811 - Val Loss: 1.2096
# Loss: 1.2265 - Accuracy: 0.8438 - Recall: 0.7531 - Precision: 0.2324 - F1: 0.3552 - AUC: 0.8784 - PR Curve Score: 0.4636
# Epoch 35/60 - Train Loss: 1.9575 - Val Loss: 1.2265
# Loss: 1.2271 - Accuracy: 0.8356 - Recall: 0.7557 - Precision: 0.2228 - F1: 0.3442 - AUC: 0.8749 - PR Curve Score: 0.4623
# Epoch 36/60 - Train Loss: 1.9441 - Val Loss: 1.2271
# Loss: 1.2162 - Accuracy: 0.8648 - Recall: 0.7320 - Precision: 0.2585 - F1: 0.3821 - AUC: 0.8753 - PR Curve Score: 0.4568
# Epoch 37/60 - Train Loss: 1.9354 - Val Loss: 1.2162
# Loss: 1.2502 - Accuracy: 0.8387 - Recall: 0.7487 - Precision: 0.2254 - F1: 0.3465 - AUC: 0.8743 - PR Curve Score: 0.4600
# Epoch 38/60 - Train Loss: 1.9556 - Val Loss: 1.2502
# Loss: 1.3103 - Accuracy: 0.8380 - Recall: 0.7574 - Precision: 0.2260 - F1: 0.3482 - AUC: 0.8757 - PR Curve Score: 0.4627
# Epoch 39/60 - Train Loss: 1.9375 - Val Loss: 1.3103
# Loss: 1.2874 - Accuracy: 0.8423 - Recall: 0.7539 - Precision: 0.2305 - F1: 0.3531 - AUC: 0.8761 - PR Curve Score: 0.4613
# Epoch 40/60 - Train Loss: 1.9233 - Val Loss: 1.2874
# Loss: 1.1839 - Accuracy: 0.8619 - Recall: 0.7285 - Precision: 0.2533 - F1: 0.3759 - AUC: 0.8744 - PR Curve Score: 0.4606
# Epoch 41/60 - Train Loss: 1.9339 - Val Loss: 1.1839
# Loss: 1.1916 - Accuracy: 0.8631 - Recall: 0.7399 - Precision: 0.2572 - F1: 0.3817 - AUC: 0.8801 - PR Curve Score: 0.4692
# Epoch 42/60 - Train Loss: 1.9294 - Val Loss: 1.1916
# Loss: 1.3008 - Accuracy: 0.8293 - Recall: 0.7671 - Precision: 0.2177 - F1: 0.3391 - AUC: 0.8791 - PR Curve Score: 0.4676
# Epoch 43/60 - Train Loss: 1.9161 - Val Loss: 1.3008
# Loss: 1.1721 - Accuracy: 0.8766 - Recall: 0.7285 - Precision: 0.2783 - F1: 0.4027 - AUC: 0.8814 - PR Curve Score: 0.4683
# Epoch 44/60 - Train Loss: 1.9135 - Val Loss: 1.1721
# Loss: 1.2225 - Accuracy: 0.8721 - Recall: 0.7329 - Precision: 0.2709 - F1: 0.3956 - AUC: 0.8822 - PR Curve Score: 0.4711
# Epoch 45/60 - Train Loss: 1.9023 - Val Loss: 1.2225
# Loss: 1.1958 - Accuracy: 0.8800 - Recall: 0.7207 - Precision: 0.2835 - F1: 0.4069 - AUC: 0.8826 - PR Curve Score: 0.4717
# Epoch 46/60 - Train Loss: 1.8997 - Val Loss: 1.1958
# Loss: 1.2510 - Accuracy: 0.8705 - Recall: 0.7277 - Precision: 0.2672 - F1: 0.3909 - AUC: 0.8788 - PR Curve Score: 0.4673
# Epoch 47/60 - Train Loss: 1.8931 - Val Loss: 1.2510
# Loss: 1.2237 - Accuracy: 0.8811 - Recall: 0.7102 - Precision: 0.2839 - F1: 0.4056 - AUC: 0.8779 - PR Curve Score: 0.4607
# Epoch 48/60 - Train Loss: 1.9020 - Val Loss: 1.2237
# Loss: 1.2500 - Accuracy: 0.8800 - Recall: 0.7224 - Precision: 0.2836 - F1: 0.4073 - AUC: 0.8815 - PR Curve Score: 0.4662
# Epoch 49/60 - Train Loss: 1.8901 - Val Loss: 1.2500
# Loss: 1.2552 - Accuracy: 0.8607 - Recall: 0.7399 - Precision: 0.2534 - F1: 0.3775 - AUC: 0.8791 - PR Curve Score: 0.4682
# Epoch 50/60 - Train Loss: 1.8897 - Val Loss: 1.2552
# Loss: 1.2053 - Accuracy: 0.8674 - Recall: 0.7250 - Precision: 0.2615 - F1: 0.3844 - AUC: 0.8793 - PR Curve Score: 0.4706
# Epoch 51/60 - Train Loss: 1.8819 - Val Loss: 1.2053
# Loss: 1.1918 - Accuracy: 0.8836 - Recall: 0.7119 - Precision: 0.2891 - F1: 0.4112 - AUC: 0.8793 - PR Curve Score: 0.4686
# Epoch 52/60 - Train Loss: 1.8757 - Val Loss: 1.1918
# Loss: 1.2645 - Accuracy: 0.8690 - Recall: 0.7382 - Precision: 0.2664 - F1: 0.3915 - AUC: 0.8815 - PR Curve Score: 0.4709
# Epoch 53/60 - Train Loss: 1.8561 - Val Loss: 1.2645
# Loss: 1.2703 - Accuracy: 0.8643 - Recall: 0.7338 - Precision: 0.2581 - F1: 0.3819 - AUC: 0.8821 - PR Curve Score: 0.4707
# Epoch 54/60 - Train Loss: 1.8665 - Val Loss: 1.2703
# Loss: 1.2795 - Accuracy: 0.8603 - Recall: 0.7426 - Precision: 0.2534 - F1: 0.3778 - AUC: 0.8845 - PR Curve Score: 0.4694
# Epoch 55/60 - Train Loss: 1.8664 - Val Loss: 1.2795
# Loss: 1.3181 - Accuracy: 0.8405 - Recall: 0.7671 - Precision: 0.2305 - F1: 0.3545 - AUC: 0.8838 - PR Curve Score: 0.4697
# Epoch 56/60 - Train Loss: 1.8696 - Val Loss: 1.3181
# Loss: 1.3134 - Accuracy: 0.8510 - Recall: 0.7461 - Precision: 0.2405 - F1: 0.3638 - AUC: 0.8805 - PR Curve Score: 0.4605
# Epoch 57/60 - Train Loss: 1.8617 - Val Loss: 1.3134
# Loss: 1.2647 - Accuracy: 0.8786 - Recall: 0.7285 - Precision: 0.2819 - F1: 0.4065 - AUC: 0.8790 - PR Curve Score: 0.4610
# Epoch 58/60 - Train Loss: 1.8597 - Val Loss: 1.2647
# Loss: 1.2767 - Accuracy: 0.8704 - Recall: 0.7356 - Precision: 0.2684 - F1: 0.3933 - AUC: 0.8796 - PR Curve Score: 0.4643
# Epoch 59/60 - Train Loss: 1.8391 - Val Loss: 1.2767
# Loss: 1.2797 - Accuracy: 0.8609 - Recall: 0.7373 - Precision: 0.2533 - F1: 0.3771 - AUC: 0.8795 - PR Curve Score: 0.4597
# Epoch 60/60 - Train Loss: 1.8420 - Val Loss: 1.2797
